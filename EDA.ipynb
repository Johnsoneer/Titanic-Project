# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as scs
import statsmodels.graphics as sg
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
X = df[['Age','Fare']]

# %%
X = X[np.isfinite(X['Age'])]
# X = np.array(X)
X[:20]
# Out:
#      Age     Fare
# 0   22.0   7.2500
# 1   38.0  71.2833
# 2   26.0   7.9250
# 3   35.0  53.1000
# 4   35.0   8.0500
# 6   54.0  51.8625
# 7    2.0  21.0750
# 8   27.0  11.1333
# 9   14.0  30.0708
# 10   4.0  16.7000
# 11  58.0  26.5500
# 12  20.0   8.0500
# 13  39.0  31.2750
# 14  14.0   7.8542
# 15  55.0  16.0000
# 16   2.0  29.1250
# 18  31.0  18.0000
# 20  35.0  26.0000
# 21  34.0  13.0000
# 22  15.0   8.0292

# %%
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111e09210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111ec2490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1120b0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11180f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11064a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1126c31d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112742550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112753a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11283d290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1128c2110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112928dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1129afe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a24510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112aa9550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112b10d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b97ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c0a890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c90b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c254d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112d89850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112dbb890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112e844d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f0d350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f71cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ff7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11306d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1130f3790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113139a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1131cdc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1131eb150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132c6a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11334c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1133c0690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113446510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1134add90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113535dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1135ab4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113630690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136a6050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11372b310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136b6d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113816fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113850f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113910b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1139989d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113a0b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113a923d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113af8e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113b7ef10>]], dtype=object)

# %%
survived = pd.crosstab(df['Survived'], df['Pclass'], rownames=['Survived'])
(survived / survived.apply(sum)).plot(kind="bar")
plt.ylabel('Percent')
plt.show()

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
print df['Survived'].value_counts()/len(df)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64
